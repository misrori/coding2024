# %% [markdown]
# <a href="https://colab.research.google.com/github/misrori/coding2024/blob/main/session4_share.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lotto game
#
# ### Steps to implement the lotto game
#
# 1. **Ask for user input**:
#    - The `get_user_numbers` function prompts the user to select numbers within a given range.
#    - The input is validated to ensure it's unique and within the range, and the final numbers are sorted.
#
# 2. **Generate random lotto numbers**:
#    - The `lotto_game` function uses `random.sample()` to draw random numbers from the specified range and sorts them.
#
# 3. **Compare user numbers with lotto draw**:
#    - The intersection of the user’s numbers and the randomly drawn numbers is calculated to find matches.
#
# 4. **Calculate odds**:
#    - The odds of winning are calculated using combinations (`math.comb`), showing the probability of matching all the numbers.
#
# 5. **Display results**:
#    - The game outputs the user's numbers, drawn numbers, matching numbers, and odds of winning.
#
# This version condenses the logic while keeping all essential functionality. Let me know if you need any further explanations!

# %%
import random
import math

# Function to get user's chosen numbers with validation
def get_user_numbers(min_number, max_number, num_to_choose):

    return user_numbers

# Lotto game function
def lotto_game(min_number, max_number, num_to_choose):


    # Display results
    print("\n----- Lotto Results -----")
    print(f"Your numbers: {player_numbers}")
    print(f"Drawn numbers: {drawn_numbers}")


# Example of calling the function
lotto_game(1, 90, 5)
# Out:
# Please choose 5 numbers between 1 and 90:
# Enter number 1: 24
# Enter number 2: 52
# Enter number 3: 65
# Enter number 4: 10
# Enter number 5: 8
#
# ----- Lotto Results -----
# Your numbers: [8, 10, 24, 52, 65]
# Drawn numbers: [11, 24, 26, 28, 50]
# Matching numbers: {24}
# You matched 1 number(s).
# Odds of winning with these numbers: 1 in 43949268 (0.000000022753508)

# %% [markdown]
# # Read CSV
# ## Git

# %% [markdown]
# ## First upload this csv to your github, then read it
#
# https://raw.githubusercontent.com/misrori/data/refs/heads/main/mtcars.csv

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/misrori/data/refs/heads/main/mtcars.csv')
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %% [markdown]
# # Read the csv with full path and relativ path

# %%
import os

os.getcwd()
# Out:
# '/content'

# %%
os.listdir('/content/')
# Out:
# ['.config', 'mtcars.csv', 'sample_data']

# %%
fullpath_data = pd.read_csv('/content/mtcars.csv')
fullpath_data.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
relativ_path_data = pd.read_csv('mtcars.csv')
relativ_path_data.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %% [markdown]
# # Read with full path and relativ path on your local computer and use tab

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# nycflights13 dataset
flights = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/flights.csv')
airlines = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/airlines.csv')
planes = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/planes.csv')
weather = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/weather.csv')

# %% [markdown]
# # Filter
# **Exercise 1: Filter Late Flights from JFK**
# Filter the flights that departed from JFK Airport ('JFK') and had a departure delay greater than 30 minutes. (15241 rows)

# %%
df1 = flights[(flights['origin'] == 'JFK') & (flights['dep_delay'] > 30)]
print(df1.shape)
# Out:
# (15241, 19)

# %% [markdown]
# **Exercise 2: Filter Long Flights with Arrival Delays**
# Filter flights with a distance greater than 1500 miles and an arrival delay greater than 15 minutes.(15553 rows)

# %%
print(df2.shape)
# Out:
# (15553, 19)

# %% [markdown]
# **Exercise 3: Filter American Airlines (AA) Flights with Short Airtime**
# Filter American Airlines (carrier code 'AA') flights with an airtime less than 2 hours.(5357 rows)

# %%
print(df3.shape)
# Out:
# (5357, 19)

# %% [markdown]
# **Exercise 4: Filter Early Morning Flights with Long Delays**
# Filter flights that departed between 4 AM and 6 AM (hour >= 4 and hour <= 6) and had a departure delay greater than 60 minutes.(602 rows)

# %%
print(df4.shape)
# Out:
# (602, 19)

# %% [markdown]
# # Groupby aggragate
# Exercise 1: Average Departure Delay by Carrier
# Calculate the average departure delay and the total number of flights for each carrier.

# %%
flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %% [markdown]
# ## Find the manufacturer (producer) of the plane that flew the most from JFK Airport in January, you can follow these steps:

# %%
df1= (
    flights[(flights["origin"]=='JFK') & (flights['month']==1) ]
    .groupby('tailnum', as_index=False)
    .agg(number_of_flights = ('tailnum', 'count'))
    .sort_values('number_of_flights', ascending=False)
    .head(1)
 )
df1
# Out:
#     tailnum  number_of_flights
# 184  N258JB                199

# %% [markdown]
# In aggragation you can do the following
# *   'count': Count the elements
# *   'sum': Sum of the values.
# *   'mean': Mean of the values.
# *   'median': Median of the values.
# *   'min': Minimum value.
# *   'max': Maximum value.
# *   'std': Standard deviation of the values.
# *   'var': Variance of the values.
# *   'first': First occurrence.
# *   'last': Last occurrence.
# *   'nunique': Count of unique values.

# %% [markdown]
# ## Task 1
# Filter the flights departing from JFK Airport (origin = 'JFK') in December, calculate the average departure delay for each airline

# %%
# Out:
#   carrier  average_dep_delay
# 4      EV          34.308642
# 0      9E          21.949949
# 2      B6          17.298529
# 6      MQ          14.689769
# 1      AA          14.146474
# 3      DL           9.703990
# 7      UA           7.404255
# 9      VX           6.993266
# 8      US           5.534296
# 5      HA          -3.142857

# %% [markdown]
# # Task 2
# Find the top 10 destinations from JFK Airport in August

# %%
# Out:
#    dest  number_of_flights
# 28  LAX                979
# 55  SFO                725
# 5   BOS                523
# 31  MCO                493
# 57  SJU                448
# ..  ...                ...
# 9   BUR                 31
# 0   ABQ                 31
# 61  STT                 27
# 53  SDF                 16
# 48  RIC                  9
#
# [64 rows x 2 columns]
